# %%
import matplotlib.pyplot as plt 
import datetime as dt
import pydarn

#Read in GRID file
stime = dt.datetime(2023, 3, 20, 16, 2)
grid_file = "/home/eoindisney/Grd/Day0.grd"
grid_data = pydarn.SuperDARNRead(grid_file).read_grid()

pydarn.Grid.plot_grid(grid_data, start_time=stime,
                      colorbar_label='Velocity (m/s)',
                      radar_label=True, line_color='blue',
                      fov_color='grey', lowlat = (50))

plt.show()
