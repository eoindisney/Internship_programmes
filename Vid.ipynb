# %%
import matplotlib.pyplot as plt 
import datetime as dt
import pydarn

#Read in GRID file for 00:10
stime_0 = dt.datetime(2023, 3, 20, 0, 10)
grid_file_0 = "/home/eoindisney/Grd/Combined_Day0.grd"
grid_data_0 = pydarn.SuperDARNRead(grid_file_0).read_grid()


#Read in GRID file for 02:10
stime_1 = dt.datetime(2023, 3, 20, 2, 10)
grid_file_1 = "/home/eoindisney/Grd/Combined_Day0.grd"
grid_data_1 = pydarn.SuperDARNRead(grid_file_1).read_grid()

#Read in GRID file for 04:10
stime_2 = dt.datetime(2023, 3, 20, 4, 10)
grid_file_2 = "/home/eoindisney/Grd/Combined_Day0.grd"
grid_data_2 = pydarn.SuperDARNRead(grid_file_2).read_grid()


#Read in GRID file for 06:10
stime_3 = dt.datetime(2023, 3, 20, 6, 10)
grid_file_3 = "/home/eoindisney/Grd/Combined_Day0.grd"
grid_data_3 = pydarn.SuperDARNRead(grid_file_3).read_grid()

#Read in GRID file for 08:10
stime_4 = dt.datetime(2023, 3, 20, 8, 10)
grid_file_4 = "/home/eoindisney/Grd/Combined_Day0.grd"
grid_data_4 = pydarn.SuperDARNRead(grid_file_4).read_grid()

#Read in GRID file for 10:10
stime_5 = dt.datetime(2023, 3, 20, 10, 10)
grid_file_5 = "/home/eoindisney/Grd/Combined_Day0.grd"
grid_data_5 = pydarn.SuperDARNRead(grid_file_5).read_grid()

#Read in GRID file for 12:10
stime_6 = dt.datetime(2023, 3, 20, 12, 10)
grid_file_6 = "/home/eoindisney/Grd/Combined_Day0.grd"
grid_data_6 = pydarn.SuperDARNRead(grid_file_6).read_grid()

#Read in GRID file for 14:10
stime_7 = dt.datetime(2023, 3, 20, 14, 10)
grid_file_7 = "/home/eoindisney/Grd/Combined_Day0.grd"
grid_data_7 = pydarn.SuperDARNRead(grid_file_7).read_grid()

#Read in GRID file for 16:10
stime_8 = dt.datetime(2023, 3, 20, 16, 10)
grid_file_8 = "/home/eoindisney/Grd/Combined_Day0.grd"
grid_data_8 = pydarn.SuperDARNRead(grid_file_8).read_grid()

#Read in GRID file for 18:10
stime_9 = dt.datetime(2023, 3, 20, 18, 10)
grid_file_9 = "/home/eoindisney/Grd/Combined_Day0.grd"
grid_data_9 = pydarn.SuperDARNRead(grid_file_9).read_grid()

#Read in GRID file for 20:10
stime_10 = dt.datetime(2023, 3, 20, 20, 10)
grid_file_10 = "/home/eoindisney/Grd/Combined_Day0.grd"
grid_data_10 = pydarn.SuperDARNRead(grid_file_10).read_grid()

#Read in GRID file for 22:10
stime_11 = dt.datetime(2023, 3, 20, 22, 10)
grid_file_11 = "/home/eoindisney/Grd/Combined_Day0.grd"
grid_data_11 = pydarn.SuperDARNRead(grid_file_11).read_grid()

#Read in GRID file for 23:50
stime_12 = dt.datetime(2023, 3, 20, 23, 50)
grid_file_12 = "/home/eoindisney/Grd/Combined_Day0.grd"
grid_data_12 = pydarn.SuperDARNRead(grid_file_12).read_grid()




plt.figure()
pydarn.Grid.plot_grid(grid_data_0, start_time=stime_0,
                      colorbar_label='Velocity (m/s)',
                      radar_label=True, line_color='blue',
                      fov_color='grey', lowlat = (50))
plt.figure()
pydarn.Grid.plot_grid(grid_data_1, start_time=stime_1,
                      colorbar_label='Velocity (m/s)',
                      radar_label=True, line_color='blue',
                      fov_color='grey', lowlat = (50))
plt.figure()
pydarn.Grid.plot_grid(grid_data_2, start_time=stime_2,
                      colorbar_label='Velocity (m/s)',
                      radar_label=True, line_color='blue',
                      fov_color='grey', lowlat = (50))
plt.figure()
pydarn.Grid.plot_grid(grid_data_3, start_time=stime_3,
                      colorbar_label='Velocity (m/s)',
                      radar_label=True, line_color='blue',
                      fov_color='grey', lowlat = (50))
plt.figure()
pydarn.Grid.plot_grid(grid_data_4, start_time=stime_4,
                      colorbar_label='Velocity (m/s)',
                      radar_label=True, line_color='blue',
                      fov_color='grey', lowlat = (50))
plt.figure()
pydarn.Grid.plot_grid(grid_data_5, start_time=stime_5,
                      colorbar_label='Velocity (m/s)',
                      radar_label=True, line_color='blue',
                      fov_color='grey', lowlat = (50))
plt.figure()
pydarn.Grid.plot_grid(grid_data_6, start_time=stime_6,
                      colorbar_label='Velocity (m/s)',
                      radar_label=True, line_color='blue',
                      fov_color='grey', lowlat = (50))
plt.figure()
pydarn.Grid.plot_grid(grid_data_7, start_time=stime_7,
                      colorbar_label='Velocity (m/s)',
                      radar_label=True, line_color='blue',
                      fov_color='grey', lowlat = (50))

plt.figure()
pydarn.Grid.plot_grid(grid_data_8, start_time=stime_8,
                      colorbar_label='Velocity (m/s)',
                      radar_label=True, line_color='blue',
                      fov_color='grey', lowlat = (50))

plt.figure()
pydarn.Grid.plot_grid(grid_data_9, start_time=stime_9,
                      colorbar_label='Velocity (m/s)',
                      radar_label=True, line_color='blue',
                      fov_color='grey', lowlat = (50))

plt.figure()
pydarn.Grid.plot_grid(grid_data_10, start_time=stime_10,
                      colorbar_label='Velocity (m/s)',
                      radar_label=True, line_color='blue',
                      fov_color='grey', lowlat = (50))

plt.figure()
pydarn.Grid.plot_grid(grid_data_11, start_time=stime_11,
                      colorbar_label='Velocity (m/s)',
                      radar_label=True, line_color='blue',
                      fov_color='grey', lowlat = (50))

plt.figure()
pydarn.Grid.plot_grid(grid_data_12, start_time=stime_12,
                      colorbar_label='Velocity (m/s)',
                      radar_label=True, line_color='blue',
                      fov_color='grey', lowlat = (50))


plt.show()
