# %%
import matplotlib.pyplot as plt 
import datetime as dt
import pydarn

#Read in GRID file for Day 0
stime = dt.datetime(2023, 3, 20, 14, 10)
grid_file_0 = "/home/eoindisney/Grd/Combined_Day0.grd"
grid_data_0 = pydarn.SuperDARNRead(grid_file_0).read_grid()


#Read in GRID file for Day 1
stime = dt.datetime(2023, 3, 21, 22, 10)
grid_file_1 = "/home/eoindisney/Grd/Combined_Day1.grd"
grid_data_1 = pydarn.SuperDARNRead(grid_file_1).read_grid()

#Read in GRID file for Day 2
stime = dt.datetime(2023, 3, 22, 18, 10)
grid_file_2 = "/home/eoindisney/Grd/Combined_Day2.grd"
grid_data_2 = pydarn.SuperDARNRead(grid_file_2).read_grid()


#Read in GRID file for Day 3
stime = dt.datetime(2023, 3, 23, 19, 10)
grid_file_3 = "/home/eoindisney/Grd/Combined_Day3.grd"
grid_data_3 = pydarn.SuperDARNRead(grid_file_3).read_grid()

#Read in GRID file for Day 4
stime = dt.datetime(2023, 3, 24, 14, 10)
grid_file_4 = "/home/eoindisney/Grd/Combined_Day4.grd"
grid_data_4 = pydarn.SuperDARNRead(grid_file_4).read_grid()

#Read in GRID file for Day 5
stime = dt.datetime(2023, 3, 25, 14, 10)
grid_file_5 = "/home/eoindisney/Grd/Combined_Day5.grd"
grid_data_5 = pydarn.SuperDARNRead(grid_file_5).read_grid()

#Read in GRID file for Day 6
stime = dt.datetime(2023, 3, 26, 10, 10)
grid_file_6 = "/home/eoindisney/Grd/Combined_Day6.grd"
grid_data_6 = pydarn.SuperDARNRead(grid_file_6).read_grid()

#Read in GRID file for Day 7
stime = dt.datetime(2023, 3, 27, 17, 10)
grid_file_7 = "/home/eoindisney/Grd/Combined_Day7.grd"
grid_data_7 = pydarn.SuperDARNRead(grid_file_7).read_grid()


plt.figure()
pydarn.Grid.plot_grid(grid_data_0, start_time=stime,
                      colorbar_label='Velocity (m/s)',
                      radar_label=True, line_color='blue',
                      fov_color='grey', lowlat = (50))
plt.figure()
pydarn.Grid.plot_grid(grid_data_1, start_time=stime,
                      colorbar_label='Velocity (m/s)',
                      radar_label=True, line_color='blue',
                      fov_color='grey', lowlat = (50))
plt.figure()
pydarn.Grid.plot_grid(grid_data_2, start_time=stime,
                      colorbar_label='Velocity (m/s)',
                      radar_label=True, line_color='blue',
                      fov_color='grey', lowlat = (50))
plt.figure()
pydarn.Grid.plot_grid(grid_data_3, start_time=stime,
                      colorbar_label='Velocity (m/s)',
                      radar_label=True, line_color='blue',
                      fov_color='grey', lowlat = (50))
plt.figure()
pydarn.Grid.plot_grid(grid_data_4, start_time=stime,
                      colorbar_label='Velocity (m/s)',
                      radar_label=True, line_color='blue',
                      fov_color='grey', lowlat = (50))
plt.figure()
pydarn.Grid.plot_grid(grid_data_5, start_time=stime,
                      colorbar_label='Velocity (m/s)',
                      radar_label=True, line_color='blue',
                      fov_color='grey', lowlat = (50))
plt.figure()
pydarn.Grid.plot_grid(grid_data_6, start_time=stime,
                      colorbar_label='Velocity (m/s)',
                      radar_label=True, line_color='blue',
                      fov_color='grey', lowlat = (50))
plt.figure()
pydarn.Grid.plot_grid(grid_data_7, start_time=stime,
                      colorbar_label='Velocity (m/s)',
                      radar_label=True, line_color='blue',
                      fov_color='grey', lowlat = (50))
plt.show()
